# %%
import arcpy
arcpy.env.overwriteOutput = True 
from arcpy.sa import *
from arcpy import env

import os
import pandas as pd
import numpy as np


workspace = os.path.join("..", 'RESULTS')
#make sure workspace directory exists
if not os.path.exists(workspace):
    os.makedirs(workspace)
    
tempspace = os.path.join(workspace, "temp")
#make sure workspace directory exists
if not os.path.exists(tempspace):
    os.makedirs(tempspace)


outspace = os.path.join(workspace, 'Sens_test_Outputs')
#make sure workspace directory exists
if not os.path.exists(outspace):
    os.makedirs(outspace)

    
from IPython.display import display, HTML
display(HTML(data="""
<style>
    div#notebook-container { width: 95%;} div#menubar-container { width: 85%; } div#maintoolbar-container { width: 99%; } </style> """))
# Out:
# <style>
#     div#notebook-container { width: 95%;} div#menubar-container { width: 85%; } div#maintoolbar-container { width: 99%; } </style>

# %%
#  path to the infrastructure layers 
InfraShpPath = os.path.join("..", 'Data/Raw/GIS/Infrastructure/Clipped')

Polyline_infrstructures = ['Relevant_Sewer_Lines_core.shp', 'ASPA_water_Distribution_core.shp', 
                           'ASPA_water_Transmission_core.shp', 'Roads_2006_core.shp'] 

Point_infrstructures = ['ASPA_CustomerMeters_core.shp', 'ASPA_water_Boosters_core.shp', 'All_sewer_LiftStations_core.shp', 'bldgs_pts_core.shp']

# %%
# Create shapefiles and a dic of the total lengths of polyline files 

OG_lenth_dic = {}
for i in Polyline_infrstructures:
    
    shapefile_to_measure = os.path.join(InfraShpPath, i)
    
    # First copy the original features to calculate and print the total lengths of polylines later
    arcpy.management.CopyFeatures(shapefile_to_measure, os.path.join(tempspace, "Length_{}".format(i)))

    fc_OG = os.path.join(tempspace, "Length_{}".format(i))
    arcpy.AddField_management(fc_OG, 'lenOG_m','DOUBLE')
    arcpy.management.CalculateField(fc_OG, "lenOG_m", "!SHAPE.geodesicLength@METERS!")   
    field = arcpy.da.TableToNumPyArray (fc_OG, "lenOG_m", skip_nulls=True)
    tot_len = field["lenOG_m"].sum()
    print("Total Original Length of {} is {} m".format(i, tot_len)) 
    OG_lenth_dic[i] = tot_len
    
    
for i in Point_infrstructures:
    fc = os.path.join(InfraShpPath, i)
    field = arcpy.da.TableToNumPyArray (fc, "FID", skip_nulls=True)
    tot_things = len(field)
    OG_lenth_dic[i] = tot_things
    print("Total number of {} is {}".format(i, tot_things))
    

# Turn the Dic into a dataframe
OG_lenth = pd.DataFrame.from_dict([OG_lenth_dic], orient='columns').transpose()
OG_lenth = OG_lenth.rename(columns={0:"Original_length_or_number"})
OG_lenth
# Out:
# Total Original Length of Relevant_Sewer_Lines_core.shp is 42315.5045899074 m
# Total Original Length of ASPA_water_Distribution_core.shp is 44057.93550498824 m
# Total Original Length of ASPA_water_Transmission_core.shp is 47137.500621334475 m
# Total Original Length of Roads_2006_core.shp is 76765.56681189116 m
# Total number of ASPA_CustomerMeters_core.shp is 1329
# Total number of ASPA_water_Boosters_core.shp is 5
# Total number of All_sewer_LiftStations_core.shp is 8
# Total number of bldgs_pts_core.shp is 2398
#                                   Original_length_or_number
# ASPA_CustomerMeters_core.shp                    1329.000000
# ASPA_water_Boosters_core.shp                       5.000000
# ASPA_water_Distribution_core.shp               44057.935505
# ASPA_water_Transmission_core.shp               47137.500621
# All_sewer_LiftStations_core.shp                    8.000000
# Relevant_Sewer_Lines_core.shp                  42315.504590
# Roads_2006_core.shp                            76765.566812
# bldgs_pts_core.shp                              2398.000000

# %%
SensTest_scenarios_dic = {}

for SenstestFile in os.listdir(os.path.join("..", "RESULTS", "Sens_test_outputs")):
    print(SenstestFile)
    scen_name = SenstestFile[:-4]
    
    # Create polygons for Surface or subsurface "flooded" areas for each of the scenarios in SLR_scenarios:
    in_raster = os.path.join("..", "RESULTS", "Sens_test_outputs", SenstestFile)
    outraster = os.path.join(tempspace, 'Temp_raster.tif')
    DaNewraster = Raster(in_raster) < 1.01                     #### Using only subsurface infrastructure for sens test 
    DaNewraster.save(outraster)

    # Convert the raster to polygons
    outPolygons = os.path.join(tempspace, 'temp.shp')
    arcpy.RasterToPolygon_conversion(outraster, outPolygons, "NO_SIMPLIFY")

    ## Delete any areas where the raster (now gridcode attribute) is 0
    arcpy.MakeFeatureLayer_management(outPolygons, "Temp_Poly")
    Selection = arcpy.SelectLayerByAttribute_management("Temp_Poly", "NEW_SELECTION", "gridcode > 0")
    arcpy.CopyFeatures_management(Selection, os.path.join(tempspace, 'FA_{}.shp'.format(scen_name)))

    results_dic = {}
    for file in os.listdir(InfraShpPath):
        if file.endswith(".shp"):
            shapefile_to_clip = os.path.join(InfraShpPath, file) 

            # Now do the actual clipping of flooded areas
            out_clipped  = os.path.join(tempspace, "{}_Flooded_{}".format(scen_name, file))
            arcpy.Clip_analysis(shapefile_to_clip, os.path.join(tempspace, 'FA_{}.shp'.format(scen_name)), out_clipped) 


            # NOW work on the Polyline_infrstructures:                                 
            if file in Polyline_infrstructures:
                arcpy.AddField_management(out_clipped, 'lenFlod_m','DOUBLE')
                arcpy.management.CalculateField(out_clipped, "lenFlod_m", "!SHAPE.geodesicLength@METERS!")   
                field = arcpy.da.TableToNumPyArray (out_clipped, "lenFlod_m", skip_nulls=True)
                flod_len = field["lenFlod_m"].sum()
                print("Length of flooded {} is {} m in {} at 1m depth".format(file, flod_len, scen_name)) 

                pct_flooded = round((flod_len/OG_lenth_dic[file])*100, 1)
                print("Total length of {} is {}, Percent of flooded is {}%  \n".format(file, OG_lenth_dic[file], pct_flooded))

                results_dic[file] = flod_len


           # NOW work on the point_infrstructures: 
            if file in Point_infrstructures:
                field = arcpy.da.TableToNumPyArray (out_clipped, "FID", skip_nulls=True)
                flood_things = len(field)
                print("Number of flooded {} is {}".format(file, flood_things))

                pct_flooded = round((flood_things/OG_lenth_dic[file])*100, 1)
                print("Total number of {} is {}, Percent of flooded is {}%  \n".format(file, OG_lenth_dic[file], pct_flooded))

                results_dic[file] = flood_things
                
        SensTest_scenarios_dic[scen_name] = results_dic
# Out:
# D2W_A_Aua_MT_1.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Aua_MT_1 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Aua_MT_1 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Aua_MT_1 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_Aua_MT_1 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Aua_MT_2.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 17
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.3%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1537.735897660915 m in D2W_A_Aua_MT_2 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.5%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1831.655962901265 m in D2W_A_Aua_MT_2 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 43
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 1.8%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Aua_MT_2 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2826.0014989312817 m in D2W_A_Aua_MT_2 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.7%
#
# D2W_A_Aua_MT_4.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 15
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.1%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1493.52635181112 m in D2W_A_Aua_MT_4 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.4%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1773.0834339353648 m in D2W_A_Aua_MT_4 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.8%
#
# Number of flooded bldgs_pts_core.shp is 38
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 1.6%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Aua_MT_4 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2701.555524808955 m in D2W_A_Aua_MT_4 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.5%
#
# D2W_A_Aua_MT_p25.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 36
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 2.7%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1816.201053033355 m in D2W_A_Aua_MT_p25 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 4.1%
#
# Length of flooded ASPA_water_Transmission_core.shp is 2106.791786840615 m in D2W_A_Aua_MT_p25 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 4.5%
#
# Number of flooded bldgs_pts_core.shp is 72
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 3.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Aua_MT_p25 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 3475.930806556402 m in D2W_A_Aua_MT_p25 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 4.5%
#
# D2W_A_Aua_MT_p5.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 29
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 2.2%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1692.7640696087951 m in D2W_A_Aua_MT_p5 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.8%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1984.7511021971147 m in D2W_A_Aua_MT_p5 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 4.2%
#
# Number of flooded bldgs_pts_core.shp is 57
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.4%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Aua_MT_p5 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 3160.6939402855114 m in D2W_A_Aua_MT_p5 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 4.1%
#
# D2W_A_Fagaalu_MT_1.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Fagaalu_MT_1 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Fagaalu_MT_1 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Fagaalu_MT_1 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_Fagaalu_MT_1 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Fagaalu_MT_2.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1594.711163662555 m in D2W_A_Fagaalu_MT_2 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.6%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1813.2615484901512 m in D2W_A_Fagaalu_MT_2 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.8%
#
# Number of flooded bldgs_pts_core.shp is 48
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1413.6646510949772 m in D2W_A_Fagaalu_MT_2 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.3%
#
# Length of flooded Roads_2006_core.shp is 2814.399117697496 m in D2W_A_Fagaalu_MT_2 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.7%
#
# D2W_A_Fagaalu_MT_4.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 20
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.5%
#
# Number of flooded ASPA_water_Boosters_core.shp is 0
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 0.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1520.496421307415 m in D2W_A_Fagaalu_MT_4 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.5%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1790.568120595731 m in D2W_A_Fagaalu_MT_4 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.8%
#
# Number of flooded bldgs_pts_core.shp is 46
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 1.9%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1391.4148747114473 m in D2W_A_Fagaalu_MT_4 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.3%
#
# Length of flooded Roads_2006_core.shp is 2757.2734183686107 m in D2W_A_Fagaalu_MT_4 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.6%
#
# D2W_A_Fagaalu_MT_p25.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 25
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.9%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1808.085572412673 m in D2W_A_Fagaalu_MT_p25 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 4.1%
#
# Length of flooded ASPA_water_Transmission_core.shp is 2079.5078294334085 m in D2W_A_Fagaalu_MT_p25 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 4.4%
#
# Number of flooded bldgs_pts_core.shp is 58
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.4%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1629.159283880547 m in D2W_A_Fagaalu_MT_p25 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.9%
#
# Length of flooded Roads_2006_core.shp is 3392.832164008368 m in D2W_A_Fagaalu_MT_p25 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 4.4%
#
# D2W_A_Fagaalu_MT_p5.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 22
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.7%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1679.5104609935952 m in D2W_A_Fagaalu_MT_p5 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.8%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1930.5096842984885 m in D2W_A_Fagaalu_MT_p5 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 4.1%
#
# Number of flooded bldgs_pts_core.shp is 52
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.2%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1524.342629875257 m in D2W_A_Fagaalu_MT_p5 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.6%
#
# Length of flooded Roads_2006_core.shp is 3181.1603134618626 m in D2W_A_Fagaalu_MT_p5 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 4.1%
#
# D2W_A_Laulii_MT_1.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Laulii_MT_1 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Laulii_MT_1 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Laulii_MT_1 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_Laulii_MT_1 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Laulii_MT_2.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Laulii_MT_2 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Laulii_MT_2 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Laulii_MT_2 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_Laulii_MT_2 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Laulii_MT_4.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Laulii_MT_4 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Laulii_MT_4 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Laulii_MT_4 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_Laulii_MT_4 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Laulii_MT_p25.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Laulii_MT_p25 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Laulii_MT_p25 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Laulii_MT_p25 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_Laulii_MT_p25 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Laulii_MT_p5.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Laulii_MT_p5 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Laulii_MT_p5 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Laulii_MT_p5 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_Laulii_MT_p5 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_minor_MT_1.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_minor_MT_1 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_minor_MT_1 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_minor_MT_1 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_minor_MT_1 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_minor_MT_2.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1596.364565828635 m in D2W_A_minor_MT_2 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.6%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1850.2018501994808 m in D2W_A_minor_MT_2 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 47
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_minor_MT_2 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2892.674121684523 m in D2W_A_minor_MT_2 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_minor_MT_4.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 19
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.4%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1586.856970909175 m in D2W_A_minor_MT_4 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.6%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1846.7438186469808 m in D2W_A_minor_MT_4 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 46
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 1.9%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1456.8192976210173 m in D2W_A_minor_MT_4 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.4%
#
# Length of flooded Roads_2006_core.shp is 2875.4422133064427 m in D2W_A_minor_MT_4 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.7%
#
# D2W_A_minor_MT_p25.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 24
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.8%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1689.340009377505 m in D2W_A_minor_MT_p25 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.8%
# Length of flooded ASPA_water_Transmission_core.shp is 1874.151387462581 m in D2W_A_minor_MT_p25 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 4.0%
#
# Number of flooded bldgs_pts_core.shp is 53
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.2%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_minor_MT_p25 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 3046.232804882143 m in D2W_A_minor_MT_p25 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 4.0%
#
# D2W_A_minor_MT_p5.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1634.134772921755 m in D2W_A_minor_MT_p5 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1866.4653414869808 m in D2W_A_minor_MT_p5 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 4.0%
#
# Number of flooded bldgs_pts_core.shp is 50
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.1%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_minor_MT_p5 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2984.051694915063 m in D2W_A_minor_MT_p5 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.9%
#
# D2W_A_Utulei_MT_1.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Utulei_MT_1 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Utulei_MT_1 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Utulei_MT_1 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_Utulei_MT_1 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Utulei_MT_2.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 20
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.5%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1622.799911553835 m in D2W_A_Utulei_MT_2 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1619.465423844051 m in D2W_A_Utulei_MT_2 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.4%
#
# Number of flooded bldgs_pts_core.shp is 45
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 1.9%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1325.9470715754771 m in D2W_A_Utulei_MT_2 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.1%
#
# Length of flooded Roads_2006_core.shp is 2645.547281872273 m in D2W_A_Utulei_MT_2 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.4%
#
# D2W_A_Utulei_MT_4.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 20
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.5%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1592.9828104512549 m in D2W_A_Utulei_MT_4 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.6%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1595.825303973241 m in D2W_A_Utulei_MT_4 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.4%
#
# Number of flooded bldgs_pts_core.shp is 45
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 1.9%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1301.724349329367 m in D2W_A_Utulei_MT_4 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.1%
#
# Length of flooded Roads_2006_core.shp is 2612.5875791072526 m in D2W_A_Utulei_MT_4 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.4%
#
# D2W_A_Utulei_MT_p25.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 35
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 2.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 2757.363028371295 m in D2W_A_Utulei_MT_p25 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 6.3%
#
# Length of flooded ASPA_water_Transmission_core.shp is 2952.361103242401 m in D2W_A_Utulei_MT_p25 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 6.3%
#
# Number of flooded bldgs_pts_core.shp is 84
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 3.5%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 2609.8415453180173 m in D2W_A_Utulei_MT_p25 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 6.2%
#
# Length of flooded Roads_2006_core.shp is 6346.238109184262 m in D2W_A_Utulei_MT_p25 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 8.3%
#
# D2W_A_Utulei_MT_p5.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 27
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 2.0%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 2208.680043227623 m in D2W_A_Utulei_MT_p5 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 5.0%
#
# Length of flooded ASPA_water_Transmission_core.shp is 2484.652853717951 m in D2W_A_Utulei_MT_p5 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 5.3%
# Number of flooded bldgs_pts_core.shp is 59
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.5%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 2000.613390331047 m in D2W_A_Utulei_MT_p5 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 4.7%
#
# Length of flooded Roads_2006_core.shp is 4707.960446175979 m in D2W_A_Utulei_MT_p5 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 6.1%
#
# D2W_A_Vaipito_MT_1.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Vaipito_MT_1 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Vaipito_MT_1 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Vaipito_MT_1 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_Vaipito_MT_1 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Vaipito_MT_2.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 13
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.0%
#
# Number of flooded ASPA_water_Boosters_core.shp is 0
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 0.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 528.697004932236 m in D2W_A_Vaipito_MT_2 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 1.2%
#
# Length of flooded ASPA_water_Transmission_core.shp is 801.282940422666 m in D2W_A_Vaipito_MT_2 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 1.7%
#
# Number of flooded bldgs_pts_core.shp is 33
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 1.4%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 288.012655588048 m in D2W_A_Vaipito_MT_2 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 0.7%
#
# Length of flooded Roads_2006_core.shp is 1112.1627267166689 m in D2W_A_Vaipito_MT_2 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 1.4%
#
# D2W_A_Vaipito_MT_4.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 13
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.0%
#
# Number of flooded ASPA_water_Boosters_core.shp is 0
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 0.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 457.93790389088 m in D2W_A_Vaipito_MT_4 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 1.0%
#
# Length of flooded ASPA_water_Transmission_core.shp is 674.577278059416 m in D2W_A_Vaipito_MT_4 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 1.4%
#
# Number of flooded bldgs_pts_core.shp is 33
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 1.4%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 201.45350704788504 m in D2W_A_Vaipito_MT_4 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 0.5%
#
# Length of flooded Roads_2006_core.shp is 902.058765140779 m in D2W_A_Vaipito_MT_4 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 1.2%
#
# D2W_A_Vaipito_MT_p25.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 66
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 5.0%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 3356.3442908663937 m in D2W_A_Vaipito_MT_p25 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 7.6%
#
# Length of flooded ASPA_water_Transmission_core.shp is 4241.632213278949 m in D2W_A_Vaipito_MT_p25 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 9.0%
#
# Number of flooded bldgs_pts_core.shp is 132
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 5.5%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 3497.06743632927 m in D2W_A_Vaipito_MT_p25 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 8.3%
#
# Length of flooded Roads_2006_core.shp is 7349.4931278006125 m in D2W_A_Vaipito_MT_p25 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 9.6%
#
# D2W_A_Vaipito_MT_p5.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 40
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 3.0%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 2473.798242311847 m in D2W_A_Vaipito_MT_p5 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 5.6%
#
# Length of flooded ASPA_water_Transmission_core.shp is 3080.269020183716 m in D2W_A_Vaipito_MT_p5 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 6.5%
#
# Number of flooded bldgs_pts_core.shp is 85
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 3.5%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 2432.387364370107 m in D2W_A_Vaipito_MT_p5 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 5.7%
#
# Length of flooded Roads_2006_core.shp is 5022.259008306531 m in D2W_A_Vaipito_MT_p5 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 6.5%
#
# D2W_A_Vatia_MT_1.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Vatia_MT_1 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Vatia_MT_1 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Vatia_MT_1 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_Vatia_MT_1 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Vatia_MT_2.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Vatia_MT_2 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Vatia_MT_2 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1450.2113466559174 m in D2W_A_Vatia_MT_2 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.4%
#
# Length of flooded Roads_2006_core.shp is 2925.2692692711325 m in D2W_A_Vatia_MT_2 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Vatia_MT_4.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1622.569004124195 m in D2W_A_Vatia_MT_4 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1848.3420614351808 m in D2W_A_Vatia_MT_4 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1450.1653073105174 m in D2W_A_Vatia_MT_4 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.4%
#
# Length of flooded Roads_2006_core.shp is 2925.2692692711325 m in D2W_A_Vatia_MT_4 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Vatia_MT_p25.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Vatia_MT_p25 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1856.995923957456 m in D2W_A_Vatia_MT_p25 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Vatia_MT_p25 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2934.852445451933 m in D2W_A_Vatia_MT_p25 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_A_Vatia_MT_p5.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_A_Vatia_MT_p5 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_A_Vatia_MT_p5 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_A_Vatia_MT_p5 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_A_Vatia_MT_p5 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_botm_multi_1.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_botm_multi_1 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# ...
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.8%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1843.280627487079 m in D2W_pump_multi_p25 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 4.2%
#
# Length of flooded ASPA_water_Transmission_core.shp is 2054.765879053706 m in D2W_pump_multi_p25 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 4.4%
#
# Number of flooded bldgs_pts_core.shp is 55
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.3%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1595.743269883321 m in D2W_pump_multi_p25 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.8%
#
# Length of flooded Roads_2006_core.shp is 3263.104522633253 m in D2W_pump_multi_p25 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 4.3%
#
# D2W_pump_multi_p5.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 23
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.7%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1760.22825176083 m in D2W_pump_multi_p5 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 4.0%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1969.1611288709933 m in D2W_pump_multi_p5 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 4.2%
#
# Number of flooded bldgs_pts_core.shp is 52
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.2%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1543.8337697539112 m in D2W_pump_multi_p5 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.6%
#
# Length of flooded Roads_2006_core.shp is 3170.336715835263 m in D2W_pump_multi_p5 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 4.1%
#
# D2W_rech_multi_1.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_rech_multi_1 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_rech_multi_1 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_rech_multi_1 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_rech_multi_1 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_rech_multi_2.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 72
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 5.4%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 3812.49383441457 m in D2W_rech_multi_2 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 8.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 4361.354255788263 m in D2W_rech_multi_2 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 9.3%
#
# Number of flooded bldgs_pts_core.shp is 155
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 6.5%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 3608.60754025524 m in D2W_rech_multi_2 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 8.5%
#
# Length of flooded Roads_2006_core.shp is 8712.007535827155 m in D2W_rech_multi_2 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 11.3%
#
# D2W_rech_multi_4.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 139
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 10.5%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 5967.884111484791 m in D2W_rech_multi_4 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 13.5%
#
# Length of flooded ASPA_water_Transmission_core.shp is 7892.058910392951 m in D2W_rech_multi_4 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 16.7%
#
# Number of flooded bldgs_pts_core.shp is 305
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 12.7%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 6550.001660324291 m in D2W_rech_multi_4 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 15.5%
#
# Length of flooded Roads_2006_core.shp is 14952.420066036339 m in D2W_rech_multi_4 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 19.5%
#
# D2W_rech_multi_p25.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 3
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 0.2%
#
# Number of flooded ASPA_water_Boosters_core.shp is 0
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 0.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 303.854868794062 m in D2W_rech_multi_p25 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 0.7%
# Length of flooded ASPA_water_Transmission_core.shp is 335.22484521243 m in D2W_rech_multi_p25 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 0.7%
#
# Number of flooded bldgs_pts_core.shp is 13
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 0.5%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 79.08293494067502 m in D2W_rech_multi_p25 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 0.2%
#
# Length of flooded Roads_2006_core.shp is 401.86945101633 m in D2W_rech_multi_p25 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 0.5%
#
# D2W_rech_multi_p5.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 6
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 0.5%
#
# Number of flooded ASPA_water_Boosters_core.shp is 0
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 0.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 349.19377975198506 m in D2W_rech_multi_p5 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 0.8%
#
# Length of flooded ASPA_water_Transmission_core.shp is 444.30492427219997 m in D2W_rech_multi_p5 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 0.9%
#
# Number of flooded bldgs_pts_core.shp is 17
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 0.7%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 95.25957856999499 m in D2W_rech_multi_p5 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 0.2%
#
# Length of flooded Roads_2006_core.shp is 553.676006239077 m in D2W_rech_multi_p5 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 0.7%
#
# D2W_Trachyte_MT_1.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_Trachyte_MT_1 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_Trachyte_MT_1 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_Trachyte_MT_1 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_Trachyte_MT_1 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_Trachyte_MT_2.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_Trachyte_MT_2 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_Trachyte_MT_2 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_Trachyte_MT_2 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_Trachyte_MT_2 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_Trachyte_MT_4.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_Trachyte_MT_4 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1848.3585975124809 m in D2W_Trachyte_MT_4 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1456.8192976210173 m in D2W_Trachyte_MT_4 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.4%
#
# Length of flooded Roads_2006_core.shp is 2926.938715975333 m in D2W_Trachyte_MT_4 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_Trachyte_MT_p25.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_Trachyte_MT_p25 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1843.528817513281 m in D2W_Trachyte_MT_p25 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
#
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1454.6288844703174 m in D2W_Trachyte_MT_p25 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.4%
#
# Length of flooded Roads_2006_core.shp is 2926.938715975533 m in D2W_Trachyte_MT_p25 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%
#
# D2W_Trachyte_MT_p5.asc
# Number of flooded All_sewer_LiftStations_core.shp is 0
# Total number of All_sewer_LiftStations_core.shp is 8, Percent of flooded is 0.0%
#
# Number of flooded ASPA_CustomerMeters_core.shp is 21
# Total number of ASPA_CustomerMeters_core.shp is 1329, Percent of flooded is 1.6%
#
# Number of flooded ASPA_water_Boosters_core.shp is 1
# Total number of ASPA_water_Boosters_core.shp is 5, Percent of flooded is 20.0%
#
# Length of flooded ASPA_water_Distribution_core.shp is 1627.9228571578751 m in D2W_Trachyte_MT_p5 at 1m depth
# Total length of ASPA_water_Distribution_core.shp is 44057.93550498824, Percent of flooded is 3.7%
#
# Length of flooded ASPA_water_Transmission_core.shp is 1853.3616472042809 m in D2W_Trachyte_MT_p5 at 1m depth
# Total length of ASPA_water_Transmission_core.shp is 47137.500621334475, Percent of flooded is 3.9%
# Number of flooded bldgs_pts_core.shp is 49
# Total number of bldgs_pts_core.shp is 2398, Percent of flooded is 2.0%
#
# Length of flooded Relevant_Sewer_Lines_core.shp is 1461.7971693460172 m in D2W_Trachyte_MT_p5 at 1m depth
# Total length of Relevant_Sewer_Lines_core.shp is 42315.5045899074, Percent of flooded is 3.5%
#
# Length of flooded Roads_2006_core.shp is 2929.177708660333 m in D2W_Trachyte_MT_p5 at 1m depth
# Total length of Roads_2006_core.shp is 76765.56681189116, Percent of flooded is 3.8%

# %% [markdown]
# ### Postprocess A: take the results dictionaries and make them dataframes

# %%
SensTest_scenarios_dic["Total_Lengths"] = OG_lenth_dic     # Add in the total lengths/numbers

output = pd.DataFrame.from_dict(SensTest_scenarios_dic, orient='columns')   # make it all a datframe
output = output.transpose()   # Transpose it

# Create a dataframe of percentage flooded
output_pct = output.copy()
for col in output: 
    tot_things = output[col].loc['Total_Lengths']
    output_pct[col] = output_pct[col]/tot_things
    
# Format percentages 
output_pct['sum']  = output_pct.sum(axis=1)/7
output_pct = output_pct.round(3)*100

# Sort by best to worst scenario 
output_pct = output_pct.sort_values("sum")

# Sort the in m df by best to worst scenario  
output['tot_buried_lines'] = output[['ASPA_water_Distribution_core.shp', 'ASPA_water_Transmission_core.shp', 'Relevant_Sewer_Lines_core.shp']].sum(axis=1)
output = output.sort_values('tot_buried_lines')

# %% [markdown]
# ### Postprocess B: Further consilidate into desired sensitivity test table

# %%
# Make a consolidated end factor, here is the average floodedness of the water and sewer lines
output["lines"] = output[['ASPA_water_Distribution_core.shp', 'ASPA_water_Transmission_core.shp', 'Relevant_Sewer_Lines_core.shp']].mean(axis=1)
output2 = output.reset_index()
output2 = output2[['index', 'lines']]

output2['index'] = output2['index'].apply(lambda x: x[4:])  # Pull out the D2W_thing
output2['Modfactor'] = output2['index'].apply(lambda x: x.split("_")[-1])   # Isolate the modfactor from the name
# arrange by infrastructure type
output2 = output2.sort_values('index')


# Group the dataframe by the modfactors 
grouped_df = output2.groupby("Modfactor")

temp_dic = {}
for key, item in grouped_df:
    # operate on each mini dataframe with like modfactors 
    want_col = item.copy()
    want_col = want_col.rename(columns={'lines': key})

    # Snazzy, this will strip out the modifactor from the end leaving just the infrastructure type
    want_col['index'] = want_col['index'].apply(lambda x: x.replace("_{}".format(key), ""))
    want_col = want_col[['index', key]]   # pull out relevant columns 
    #want_col = want_col.set_index('index')   # set index for the concat

    temp_dic[key] = want_col

# lengths is annoying and in there
if 'Lengths' in temp_dic.keys():    
    del temp_dic['Lengths']
    
# Now wrap it all into one dataframe 
df = pd.DataFrame(columns=["index"]) # Create an empty dataframe, this will be your final dataframe
for key in temp_dic:
    df = df.merge(temp_dic[key], on="index", how='outer') # Add your sub_df one by one

#reorder Columns 
df = df[['index', 'p25','p5', '1', '2', '4',]]

# set up percent difference frame
df_pct_diff = df[['index']].copy()
df_pct_diff["25% multiplier"] = round((-df["1"] + df["p25"])/df["1"]*100, 1)
df_pct_diff["50% multiplier"] = round((-df["1"] + df["p5"])/df["1"]*100, 1)
df_pct_diff["100% multiplier"] = 100
df_pct_diff["200% multiplier"] = round((-df["1"] + df["2"])/df["1"]*100, 1)
df_pct_diff["400% multiplier"] = round((-df["1"] + df["4"])/df["1"]*100, 1)

#Save csvs
df_pct_diff.to_csv(os.path.join("..", 'RESULTS', 'output_pct_sens_test.csv'))
df.to_csv(os.path.join("..", 'RESULTS', 'output_sens_test.csv'))

df_pct_diff
# Out:
#               index  25% multiplier  50% multiplier  100% multiplier  \
# 0          A_Aua_MT             8.9             4.0              100
# 1      A_Fagaalu_MT            11.6             3.9              100
# 2       A_Laulii_MT             0.0             0.0              100
# 3       A_Utulei_MT            68.3            35.4              100
# 4      A_Vaipito_MT           124.5            61.6              100
# 5        A_Vatia_MT             0.1             0.0              100
# 6        A_minor_MT             1.7             0.4              100
# 7          Dikes_MT             2.2            -0.4              100
# 8   Pago_inner_E_MT            -0.8            -0.1              100
# 9   Pago_inner_W_MT            11.1             4.6              100
# 10    Pago_outer_MT             6.0             3.3              100
# 11      Trachyte_MT            -0.3             0.0              100
# 12       botm_multi           290.0           130.3              100
# 13       cond_multi             6.3             2.2              100
# 14       pump_multi            11.1             6.7              100
# 15       rech_multi           -85.5           -82.0              100
#
#     200% multiplier  400% multiplier
# 0              -2.3             -4.3
# 1              -2.5             -4.9
# 2               0.0              0.0
# 3              -7.6             -9.2
# 4             -67.3            -73.0
# 5              -0.2             -0.4
# 6              -0.7             -1.1
# 7               0.0             -0.0
# 8              -0.3             -1.1
# 9               5.3              6.0
# 10             -6.6            -15.3
# 11              0.0             -0.2
# 12            -78.4            -84.4
# 13             -1.4             -2.1
# 14            -20.1            -68.7
# 15            138.4            312.9
